# %%
# %pip install xgboost
# Out:
# ...
#   Obtaining dependency information for xgboost from https://files.pythonhosted.org/packages/e2/7b/8c1b410cd0604cee9a167a19f7e1746f5b92ae7d02ad574ab560b73c5a48/xgboost-2.1.1-py3-none-win_amd64.whl.metadata
# ...
#    ---------------------------------------- 0.0/124.9 MB ? eta -:--:--
#    ---------------------------------------- 0.0/124.9 MB ? eta -:--:--
#    ---------------------------------------- 0.0/124.9 MB ? eta -:--:--
#    ---------------------------------------- 0.0/124.9 MB ? eta -:--:--
#    ---------------------------------------- 0.0/124.9 MB ? eta -:--:--
#    ---------------------------------------- 0.0/124.9 MB ? eta -:--:--
#    ---------------------------------------- 0.0/124.9 MB ? eta -:--:--
#    ---------------------------------------- 0.0/124.9 MB ? eta -:--:--
#    ---------------------------------------- 0.0/124.9 MB ? eta -:--:--
#    ---------------------------------------- 0.0/124.9 MB ? eta -:--:--
# ...

# %%
import joblib
import numpy as np
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score
import matplotlib.colors as mcolors
# import xgboost as xgb


# Load the saved model
model = joblib.load('taxi_model.pkl')

# %%
time_in_minutes = int("7") * 60  # Convert hour to total minutes
print("Time in minutes as integer", time_in_minutes)
time_for_prediction = pd.DataFrame({'Hour': [time_in_minutes]})
print(time_for_prediction)

# Predict the probabilities for each region based on time
try:
    predicted_region_proba = model.predict_proba(time_for_prediction)
    # Log the predictions to the terminal/console
    print("Prediction results: ", predicted_region_proba)
except Exception as e:
    print(f"Error while making predictions: {e}")
# Out:
# Time in minutes as integer 420
#    Hour
# 0   420
# Prediction results:  [[0.13155876 0.05721219 0.01226526 0.04875518 0.08981265 0.03569518
#   0.18200651 0.1588916  0.08701745 0.00056237 0.01195712 0.00053734
#   0.02119348 0.02701268 0.02386282 0.02461475 0.01557906 0.00773718
#   0.0255236  0.03820484]]
